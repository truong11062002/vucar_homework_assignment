# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split, RandomizedSearchCV

from sklearn import svm
import xgboost as xgb

from sklearn.metrics import accuracy_score

from scipy.stats import randint

# %%
data = pd.read_csv('./car.csv')
data = data.drop_duplicates()
data = data.drop(columns=['id', 'list_id', 'list_time', 'origin', 'seats', 'gearbox', 'color', 'mileage_v2'])
data
# Out:
#         manufacture_date      brand      model              type    fuel  \
# 0                   1980       Jeep         A2  SUV / Cross over  petrol
# 1                   2021      Honda       City             Sedan  petrol
# 2                   2016        Kia        Rio               NaN  petrol
# 3                   2020     Toyota       Vios             Sedan  petrol
# 4                   2001       Fiat      Siena               NaN  petrol
# ...                  ...        ...        ...               ...     ...
# 317611              2004  Ssangyong      Musso  SUV / Cross over  petrol
# 317613              2015        Kia         K3             Sedan  petrol
# 317617              2018    Hyundai  Grand i10         Hatchback  petrol
# 317618              2007    Hyundai   Veracruz  SUV / Cross over     oil
# 317623              2018    Hyundai  Grand i10         Hatchback  petrol
#
#               price condition
# 0       380000000.0      used
# 1       455000000.0      used
# 2       295000000.0      used
# 3       368000000.0      used
# 4        73000000.0      used
# ...             ...       ...
# 317611   95000000.0      used
# 317613  370000000.0      used
# 317617  315000000.0      used
# 317618  535000000.0      used
# 317623  305000000.0      used
#
# [81458 rows x 7 columns]

# %%
print(data.shape)
print(data.dtypes)
# Out:
# (81458, 7)
# manufacture_date      int64
# brand                object
# model                object
# type                 object
# fuel                 object
# price               float64
# condition            object
# dtype: object

# %%
data.describe()
# Out:
#        manufacture_date         price
# count      81458.000000  8.142800e+04
# mean        2015.880282  5.972179e+08
# std           33.717270  6.841050e+08
# min           -1.000000  1.310720e+06
# 25%         2014.000000  2.990000e+08
# 50%         2018.000000  4.690000e+08
# 75%         2021.000000  6.800000e+08
# max         2023.000000  3.750000e+10

# %% [markdown]
# ### **manufacture_date**

# %%
print(f'Number of NaN: {data["manufacture_date"].isna().sum()}')
print(f'Unique values: {data["manufacture_date"].unique()}')
# Out:
# Number of NaN: 0
# Unique values: [1980 2021 2016 2020 2001 2022 2018 2009 2015 2008 2023 2007 2004 2019
#  2014 2010 2012 1995 2003 2011 2017 2006 1999 2013 1994 1992 2000 2002
#  1996 2005 1998 1997 1986   -1 1990 1985 1989 1984 1993 1988 1991 1987
#  1983 1982]

# %% [markdown]
# Check rows with `manufacture_data = -1`

# %%
selected_rows = data[data['manufacture_date'] == -1]
selected_rows
# Out:
#         manufacture_date brand model type fuel        price condition
# 1727                  -1   NaN   NaN  NaN  NaN  190000000.0      used
# 4455                  -1   NaN   NaN  NaN  NaN  190000000.0      used
# 5525                  -1   NaN   NaN  NaN  NaN  190000000.0      used
# 6108                  -1   NaN   NaN  NaN  NaN  190000000.0      used
# 6744                  -1   NaN   NaN  NaN  NaN  190000000.0      used
# 44958                 -1   NaN   NaN  NaN  NaN  890000000.0      used
# 87030                 -1   NaN   NaN  NaN  NaN  890000000.0      used
# 102984                -1   NaN   NaN  NaN  NaN  890000000.0      used
# 116660                -1   NaN   NaN  NaN  NaN  890000000.0      used
# 147688                -1   NaN   NaN  NaN  NaN  890000000.0      used
# 259549                -1   NaN   NaN  NaN  NaN  200000000.0      used
# 259687                -1   NaN   NaN  NaN  NaN  180000000.0      used
# 262146                -1   NaN   NaN  NaN  NaN  180000000.0      used
# 262641                -1   NaN   NaN  NaN  NaN  200000000.0      used
# 262714                -1   NaN   NaN  NaN  NaN  200000000.0      used
# 263109                -1   NaN   NaN  NaN  NaN  180000000.0      used
# 263715                -1   NaN   NaN  NaN  NaN  200000000.0      used
# 263759                -1   NaN   NaN  NaN  NaN  180000000.0      used
# 264499                -1   NaN   NaN  NaN  NaN  180000000.0      used
# 264591                -1   NaN   NaN  NaN  NaN  200000000.0      used
# 265013                -1   NaN   NaN  NaN  NaN  200000000.0      used
# 266200                -1   NaN   NaN  NaN  NaN  200000000.0      used

# %%
data = data[data['manufacture_date'] != -1]
data
# Out:
#         manufacture_date      brand      model              type    fuel  \
# 0                   1980       Jeep         A2  SUV / Cross over  petrol
# 1                   2021      Honda       City             Sedan  petrol
# 2                   2016        Kia        Rio               NaN  petrol
# 3                   2020     Toyota       Vios             Sedan  petrol
# 4                   2001       Fiat      Siena               NaN  petrol
# ...                  ...        ...        ...               ...     ...
# 317611              2004  Ssangyong      Musso  SUV / Cross over  petrol
# 317613              2015        Kia         K3             Sedan  petrol
# 317617              2018    Hyundai  Grand i10         Hatchback  petrol
# 317618              2007    Hyundai   Veracruz  SUV / Cross over     oil
# 317623              2018    Hyundai  Grand i10         Hatchback  petrol
#
#               price condition
# 0       380000000.0      used
# 1       455000000.0      used
# 2       295000000.0      used
# 3       368000000.0      used
# 4        73000000.0      used
# ...             ...       ...
# 317611   95000000.0      used
# 317613  370000000.0      used
# 317617  315000000.0      used
# 317618  535000000.0      used
# 317623  305000000.0      used
#
# [81436 rows x 7 columns]

# %% [markdown]
# ### **brand**

# %%
print(f'Number of NaN: {data["brand"].isna().sum()}')
print(f'Number of unique values: {data["brand"].nunique()}')
print(f'Unique values: {sorted(data["brand"].unique())}')
# Out:
# Number of NaN: 0
# Number of unique values: 67
# Unique values: ['Acura', 'Asia', 'Aston Martin', 'Audi', 'BMW', 'BYD', 'Baic', 'Bentley', 'Buick', 'Cadillac', 'Changan', 'Chery', 'Chevrolet', 'Chrysler', 'Citroen', 'Daewoo', 'Daihatsu', 'Dodge', 'Ferrari', 'Fiat', 'Ford', 'Gaz', 'Haima', 'Haval', 'Hãng khác', 'Honda', 'HongQi', 'Hyundai', 'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Lada', 'Lamborghini', 'LandRover', 'Lexus', 'Lifan', 'Lincoln', 'Luxgen', 'MG', 'Maserati', 'Maybach', 'Mazda', 'Mekong', 'Mercedes Benz', 'Mini', 'Mitsubishi', 'Nissan', 'Peugeot', 'Porsche', 'Proton', 'RAM', 'Renault', 'Rolls Royce', 'Rover', 'SYM', 'Samsung', 'Smart', 'Ssangyong', 'Subaru', 'Suzuki', 'Toyota', 'Vinfast', 'Volkswagen', 'Volvo', 'Zotye']

# %% [markdown]
# ### **model**

# %%
print(f'Number of NaN: {data["model"].isna().sum()}')
print(f'Number of unique values: {data["model"].nunique()}')
print(f'Unique values: {sorted(data["model"].unique())}')
# Out:
# Number of NaN: 0
# Number of unique values: 521
# Unique values: ['1 Series', '107', '1083', '1500', '190', '2', '2 Series', '200', '2008', '205', '206', '208', '2108', '3', '3 Series', '3000GT', '3008', '300C', '305', '308', '323', '4 Runner', '4 Series', '404', '405', '408', '5', '5 Series', '500', '5008', '505', '508', '520', '6', '6 Series', '620', '626', '7', '7 MPV', '7 SUV', '7 Series', '718', '86', '911', '929', '940', 'A Class', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'AMG', 'APV', 'Accent', 'Accord', 'Acononline', 'Aerio', 'Albea', 'Almera', 'Alphard', 'Altima', 'Alto', 'Amigo', 'Aranos', 'Aristo', 'Aspire', 'Astro', 'Atenza', 'Atos', 'Attrage', 'Aurion', 'Avalon', 'Avanlanche', 'Avante', 'Avanza', 'Aveo', 'Aygo', 'Azera', 'B Class', 'BR-V', 'BT 50', 'Balenno', 'Beetle', 'Beijing X7', 'Bluebird', 'Boxster', 'Brio', 'C Class', 'CD5', 'CJ', 'CL Class', 'CLA Class', 'CLK Class', 'CLS Class', 'CR V', 'CR X', 'CTS', 'CX 3', 'CX 5', 'CX 8', 'CX 9', 'CX-30', 'Cadenza', 'Caldina', 'Camaro', 'Cami', 'Camry', 'Captiva', 'Caravan', 'Carens', 'Carnival', 'Cavalier', 'Cayenne', 'Cayman', 'Cedric', 'Cefiro', 'Celerio', 'Celica', 'Centennial', 'Century', 'Cerato', 'Cerato Koup', 'Challenger', 'Charade', 'Chevyvan', 'Ciaz', 'Cielo', 'Citivan', 'City', 'Civic', 'Click', 'Clubman', 'Colorado', 'Colt', 'Concord', 'Continental', 'Contour', 'Cooper', 'Corolla', 'Corolla Altis', 'Corolla Cross', 'Corona', 'County', 'Coupe', 'Cressida', 'Creta', 'Crown', 'Cruiser', 'Cruze', 'Cultis wagon', 'Custin', 'Defender', 'Deville', 'Diamante', 'Discovery', 'Dmax', 'Doblo', 'Dòng khác', 'Duster', 'Dòng khác', 'E Class', 'ES', 'EX', 'Eclipse', 'EcoSport', 'Elantra', 'Elgrand', 'Encore GX', 'Enterprise', 'Eon', 'Eos', 'Ertiga', 'Escalade', 'Escape', 'Escort', 'Espero', 'Everest', 'Explorer', 'Express', 'F 150', 'F 350', 'F PACE', 'F0', 'FVR', 'FX', 'Fadil', 'Family', 'Fiesta', 'Fj cruiser', 'Flying Spur', 'Focus', 'Focus C Max', 'Forester', 'Forfour', 'Forte', 'Fortuner', 'Fortwo', 'Freelander', 'Fucion', 'G Class', 'GL Class', 'GLA Class', 'GLB', 'GLC', 'GLC Class', 'GLE Class', 'GLK Class', 'GLS Class', 'GS', 'GT Coupe', 'GX', 'Galant', 'Galloper', 'Gazele', 'Genesis', 'Gentra', 'GentraX', 'Getz', 'Ghost', 'Gold', 'Grand Starex', 'Grand Voyager', 'Grand i10', 'Grand livina', 'Grand vitara', 'Grandeur', 'Grandis', 'Grunder', 'H 1', 'H6', 'H9', 'HR-V', 'HS', 'Hi lander', 'Hiace', 'Highlander', 'Hijet', 'Hilux', 'Honor', 'Huracan', 'IQ', 'IS', 'Impreza', 'Innova', 'Innova Cross', 'Ioniq 5', 'Jazz', 'Jolie', 'Journey', 'Juke', 'K3', 'K5', 'Ka', 'Kicks', 'Koleos', 'Kona', 'Korando', 'Kyron', 'L300', 'LM350', 'LS', 'LX', 'Lacetti', 'Lancer', 'Land Cruiser', 'Land Cruiser Prado', 'Lanos', 'Lantra', 'Laser', 'Latitude', 'Laurel', 'LeBaron', 'Leganza', 'Legend', 'Levante', 'Levorg', 'Libero', 'Liberty', 'Liteace', 'Livina', 'Lumina', 'Lux A2.0', 'Lux SA2.0', 'M Class', 'M couper', 'M3', 'M6', 'M7', 'MB', 'MDX', 'ML Class', 'MX 3', 'MX 6', 'Macan', 'Magentis', 'Magnus', 'Matiz', 'Maxima', 'Maybach', 'Megane', 'Midi', 'Mighty', 'Mirage', 'Mondeo', 'Montero', 'Morning', 'Mu X', 'Mulsanne', 'Murano', 'Musso', 'Mustang', 'NMR', 'NPR', 'NSX', 'NX', 'Navara', 'Navigator', 'New Beetle', 'New Yorker', 'Nubira', 'Odyssey', 'One', 'Optima', 'Orlando', 'Outback', 'Outlander', 'Outlander Sport', 'Pajero', 'Pajero Sport', 'Palisade', 'Panamera', 'Paso', 'Passat', 'Perdana', 'Phantom', 'Picanto', 'Pick up', 'Pickup', 'Pilot', 'Pixo', 'Polo', 'Potentia', 'Prado', 'Prairie', 'Pregio', 'Premacy', 'Premio', 'President', 'Previa', 'Pride', 'Prius', 'Pronto', 'Q2', 'Q3', 'Q5', 'Q7', 'Q8', 'QKR', 'QQ3', 'QX', 'QX60', 'QX80', 'Qashqai', 'Quoris', 'R Class', 'RAV4', 'RC', 'RCZ', 'RDX', 'RX', 'Raize', 'Range Rover', 'Range Rover Evoque', 'Range Rover Sport', 'Range Rover Velar', 'Range Rover Vogue', 'Ranger', 'Rexton', 'Rio', 'Roadster', 'Rogue', 'Rondo', 'Rush', 'S 10', 'S Class', 'S3', 'S60', 'S7', 'S8', 'S90', 'SLK Class', 'SM3', 'SRX', 'SSR', 'Samirai', 'Sandero', 'Santa Fe', 'Scirocco', 'Sedona', 'Seltos', 'Sentra', ' ...

# %% [markdown]
# ### **type**

# %%
print(f'Number of NaN: {data["type"].isna().sum()}')
print(f'Number of unique values: {data["type"].nunique()}')
print(f'Unique values: {data["type"].unique()}')
# Out:
# Number of NaN: 11126
# Number of unique values: 9
# Unique values: ['SUV / Cross over' 'Sedan' nan 'Minivan (MPV)' 'Van' 'Hatchback'
#  'Pick-up (bán tải)' 'Coupe (2 cửa)' 'Kiểu dáng khác' 'Mui trần']

# %%
# Fill Nan with the most frequent value
data['type'] = data['type'].fillna(data['type'].mode()[0])
# Out:
# C:\Users\DTBKhanh\AppData\Local\Temp\ipykernel_12248\3301231890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['type'] = data['type'].fillna(data['type'].mode()[0])

# %% [markdown]
# ### **fuel**

# %%
print(f'Number of NaN: {data["fuel"].isna().sum()}')
print(f'Number of unique values: {data["fuel"].nunique()}')
print(f'Unique values: {data["fuel"].unique()}')
# Out:
# Number of NaN: 14
# Number of unique values: 4
# Unique values: ['petrol' 'oil' 'electric' 'hybrid' nan]

# %%
# Fill Nan with the most frequent value
data['fuel'] = data['fuel'].fillna(data['fuel'].mode()[0])
# Out:
# C:\Users\DTBKhanh\AppData\Local\Temp\ipykernel_12248\1156484555.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['fuel'] = data['fuel'].fillna(data['fuel'].mode()[0])

# %% [markdown]
# ### **condition**

# %%
print(f'Number of NaN: {data["condition"].isna().sum()}')
print(f'Number of unique values: {data["condition"].nunique()}')
print(f'Unique values: {data["condition"].unique()}')
# Out:
# Number of NaN: 0
# Number of unique values: 2
# Unique values: ['used' 'new']

# %% [markdown]
# ### **price**

# %%
print(f'Number of NaN: {data["price"].isna().sum()}')
print(f'Number of unique values: {data["price"].nunique()}')
print(f'Unique values: {data["price"].unique()}')
# Out:
# Number of NaN: 30
# Number of unique values: 2095
# Unique values: [3.80000e+08 4.55000e+08 2.95000e+08 ... 2.58000e+07 1.45555e+08
#  1.23409e+09]

# %%
# Fill Nan with the mean value
data['price'] = data['price'].fillna(data['price'].mean())
# Out:
# C:\Users\DTBKhanh\AppData\Local\Temp\ipykernel_12248\2732459873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['price'] = data['price'].fillna(data['price'].mean())

# %%
# Rename type column to type_car
data = data.rename(columns={'type': 'type_car'})

# %% [markdown]
# ### **Save data**

# %%
data.to_csv('./car_final.csv')
